# %% [markdown]
# ### Import dependencies

# %%
import os, sys, inspect
import numpy as np
import pandas as pd
import math
import random
import sklearn
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse.linalg import svds
import matplotlib.pyplot as plt

# %% [markdown]
# ### Get/Insert current and project root path

# %%
currdir =  os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
rootdir =  os.path.dirname(currdir)
sys.path.insert(0, rootdir)

# %%
from rcpy.model import Popularity
from rcpy.model import ContentFilter
from rcpy.model import CollaborativeFilter
from rcpy.model.evaluator import RecallTopN

# %% [markdown]
# ### Load data

# %%
articles_df = pd.read_csv(os.path.join(rootdir, "rcpy", "data", "ext", "shared_articles.csv"))
articles_df.head(5)
# Out:
#     timestamp        eventType            contentId       authorPersonId  \
# 0  1459192779  CONTENT REMOVED -6451309518266745024  4340306774493623681
# 1  1459193988   CONTENT SHARED -4110354420726924665  4340306774493623681
# 2  1459194146   CONTENT SHARED -7292285110016212249  4340306774493623681
# 3  1459194474   CONTENT SHARED -6151852268067518688  3891637997717104548
# 4  1459194497   CONTENT SHARED  2448026894306402386  4340306774493623681
#
#        authorSessionId authorUserAgent authorRegion authorCountry contentType  \
# 0  8940341205206233829             NaN          NaN           NaN        HTML
# 1  8940341205206233829             NaN          NaN           NaN        HTML
# 2  8940341205206233829             NaN          NaN           NaN        HTML
# 3 -1457532940883382585             NaN          NaN           NaN        HTML
# 4  8940341205206233829             NaN          NaN           NaN        HTML
#
#                                                  url  \
# 0  http://www.nytimes.com/2016/03/28/business/dea...
# 1  http://www.nytimes.com/2016/03/28/business/dea...
# 2  http://cointelegraph.com/news/bitcoin-future-w...
# 3  https://cloudplatform.googleblog.com/2016/03/G...
# 4  https://bitcoinmagazine.com/articles/ibm-wants...
#
#                                                title  \
# 0  Ethereum, a Virtual Currency, Enables Transact...
# 1  Ethereum, a Virtual Currency, Enables Transact...
# 2  Bitcoin Future: When GBPcoin of Branson Wins O...
# 3                       Google Data Center 360° Tour
# 4  IBM Wants to "Evolve the Internet" With Blockc...
#
#                                                 text lang
# 0  All of this work is still very early. The firs...   en
# 1  All of this work is still very early. The firs...   en
# 2  The alarm clock wakes me at 8:00 with stream o...   en
# 3  We're excited to share the Google Data Center ...   en
# 4  The Aite Group projects the blockchain market ...   en

# %%
interactions_df = pd.read_csv(os.path.join(rootdir, "rcpy","data", "ext", "users_interactions.csv"))
interactions_df.head(5)
# Out:
#     timestamp eventType            contentId             personId  \
# 0  1465413032      VIEW -3499919498720038879 -8845298781299428018
# 1  1465412560      VIEW  8890720798209849691 -1032019229384696495
# 2  1465416190      VIEW   310515487419366995 -1130272294246983140
# 3  1465413895    FOLLOW   310515487419366995   344280948527967603
# 4  1465412290      VIEW -7820640624231356730  -445337111692715325
#
#              sessionId                                          userAgent  \
# 0  1264196770339959068                                                NaN
# 1  3621737643587579081  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...
# 2  2631864456530402479                                                NaN
# 3 -3167637573980064150                                                NaN
# 4  5611481178424124714                                                NaN
#
#   userRegion userCountry
# 0        NaN         NaN
# 1         NY          US
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN

# %% [markdown]
# ### Perfom data munging
# Associate a weight/rank to each event type according to its strength.

# %%
event_type_keys = interactions_df.eventType.unique()
event_type_keys
# Out:
# array(['VIEW', 'FOLLOW', 'BOOKMARK', 'LIKE', 'COMMENT CREATED'],
#       dtype=object)

# %%
event_type_values = [1.0, 2.0, 2.5, 3.0, 4.0]
event_type_values
# Out:
# [1.0, 2.0, 2.5, 3.0, 4.0]

# %%
event_type_dict = dict((key, value) for (key, value) in zip(event_type_keys, event_type_values))

# %%
interactions_df["eventStrength"] = interactions_df.eventType.apply(lambda x: event_type_dict[x])

# %% [markdown]
# To prevent the user-cold-start problem eliminate user with interactions less than 5.

# %%
interactions_count_df = pd.DataFrame(interactions_df.groupby(["personId"])["contentId"].nunique()).reset_index()
interactions_count_df.rename(columns={"contentId": "interactionsCount"}, inplace=True)

# %%
users_with_enough_interactions = interactions_count_df[interactions_count_df.interactionsCount >= 5]
users_with_enough_interactions.head()
# Out:
#               personId  interactionsCount
# 0 -9223121837663643404                 43
# 1 -9212075797126931087                  5
# 2 -9207251133131336884                  7
# 3 -9199575329909162940                 11
# 4 -9196668942822132778                  7

# %%
print('# of interactions: %d' % len(interactions_df))
selected_interactions_df = interactions_df.merge(
    users_with_enough_interactions,
    how="right",
    left_on="personId",
    right_on="personId")
print('# of interactions from users with at least 5 interactions: %d' % len(selected_interactions_df))
selected_interactions_df.head()
# Out:
# # of interactions: 72312
# # of interactions from users with at least 5 interactions: 69868
#     timestamp eventType            contentId             personId  \
# 0  1465413032      VIEW -3499919498720038879 -8845298781299428018
# 1  1465413046      VIEW -3499919498720038879 -8845298781299428018
# 2  1464190235      VIEW  6437568358552101410 -8845298781299428018
# 3  1459429221      VIEW -4760639635023250284 -8845298781299428018
# 4  1459274156      VIEW -6142462826726347616 -8845298781299428018
#
#              sessionId                                          userAgent  \
# 0  1264196770339959068                                                NaN
# 1  1264196770339959068  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5...
# 2 -1157447994463607871  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4...
# 3 -5149610736659242149  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4...
# 4 -6283148774987755959  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4...
#
#   userRegion userCountry  eventStrength  interactionsCount
# 0        NaN         NaN            1.0                130
# 1         SP          BR            1.0                130
# 2         SP          BR            1.0                130
# 3         SP          BR            1.0                130
# 4         SP          BR            1.0                130

# %% [markdown]
# Aggregate all the user interactions in a single score. (sum of weighted interactions strength smoothed by a log transformation)

# %%
full_interactions_df = selected_interactions_df\
    .groupby(["personId", "contentId"])["eventStrength"]\
    .sum() \
    .apply(lambda x: math.log(1+x,2)) \
    .reset_index()
full_interactions_df.head()
# Out:
#               personId            contentId  eventStrength
# 0 -9223121837663643404 -8949113594875411859       1.000000
# 1 -9223121837663643404 -8377626164558006982       1.000000
# 2 -9223121837663643404 -8208801367848627943       1.000000
# 3 -9223121837663643404 -8187220755213888616       1.000000
# 4 -9223121837663643404 -7423191370472335463       3.169925

# %% [markdown]
# ### Build evaluation data

# %%
user_column = "personId"
content_column = "contentId"
score_column = "eventStrength"
n_factors = 15

# %%
train_interactions_df, test_interactions_df = train_test_split(
    full_interactions_df,
    stratify=full_interactions_df[user_column],
    test_size=0.20,
    random_state=42)

# %%
print('# interactions on Train set: %d' % len(train_interactions_df))
print('# interactions on Test set: %d' % len(test_interactions_df))
# Out:
# # interactions on Train set: 31284
# # interactions on Test set: 7822

# %%
full_interactions_df = full_interactions_df.set_index(user_column)
train_interactions_df = train_interactions_df.set_index(user_column)
test_interactions_df = test_interactions_df.set_index(user_column)

# full_interactions_df = full_interactions_df.reset_index()
# train_interactions_df = train_interactions_df.reset_index()
# test_interactions_df = test_interactions_df.reset_index()

# %%
# create user-itm score data frame
scores_df = train_interactions_df.pivot(columns=content_column, values=score_column).fillna(0)
print("user-item scores data frame: ({:d}, {:d})".format(scores_df.shape[0], scores_df.shape[1]))
scores_df.head(10)
# Out:
# user-item scores data frame: (1140, 2926)
# contentId             -9222795471790223670  -9216926795620865886  \
# personId
# -9223121837663643404                   0.0              0.000000
# -9212075797126931087                   0.0              0.000000
# -9207251133131336884                   0.0              2.321928
# -9199575329909162940                   0.0              0.000000
# -9196668942822132778                   0.0              0.000000
# -9188188261933657343                   0.0              0.000000
# -9172914609055320039                   0.0              0.000000
# -9156344805277471150                   0.0              0.000000
# -9120685872592674274                   0.0              0.000000
# -9109785559521267180                   0.0              0.000000
#
# contentId             -9194572880052200111  -9192549002213406534  \
# personId
# -9223121837663643404                   0.0                   0.0
# -9212075797126931087                   0.0                   0.0
# -9207251133131336884                   0.0                   0.0
# -9199575329909162940                   0.0                   0.0
# -9196668942822132778                   0.0                   0.0
# -9188188261933657343                   0.0                   0.0
# -9172914609055320039                   0.0                   0.0
# -9156344805277471150                   0.0                   0.0
# -9120685872592674274                   0.0                   0.0
# -9109785559521267180                   0.0                   0.0
#
# contentId             -9190737901804729417  -9189659052158407108  \
# personId
# -9223121837663643404                   0.0                   0.0
# -9212075797126931087                   0.0                   0.0
# -9207251133131336884                   0.0                   0.0
# -9199575329909162940                   0.0                   0.0
# -9196668942822132778                   0.0                   0.0
# -9188188261933657343                   0.0                   0.0
# -9172914609055320039                   0.0                   0.0
# -9156344805277471150                   0.0                   0.0
# -9120685872592674274                   0.0                   0.0
# -9109785559521267180                   0.0                   0.0
#
# contentId             -9176143510534135851  -9172673334835262304  \
# personId
# -9223121837663643404                   0.0                   0.0
# -9212075797126931087                   0.0                   0.0
# -9207251133131336884                   0.0                   0.0
# -9199575329909162940                   0.0                   0.0
# -9196668942822132778                   0.0                   0.0
# -9188188261933657343                   0.0                   0.0
# -9172914609055320039                   0.0                   0.0
# -9156344805277471150                   0.0                   0.0
# -9120685872592674274                   0.0                   0.0
# -9109785559521267180                   0.0                   0.0
#
# contentId             -9171475473795142532  -9166778629773133902  \
# personId
# -9223121837663643404                   0.0                   0.0
# -9212075797126931087                   0.0                   0.0
# -9207251133131336884                   0.0                   0.0
# -9199575329909162940                   0.0                   0.0
# -9196668942822132778                   0.0                   0.0
# -9188188261933657343                   0.0                   0.0
# -9172914609055320039                   0.0                   0.0
# -9156344805277471150                   0.0                   0.0
# -9120685872592674274                   0.0                   0.0
# -9109785559521267180                   0.0                   0.0
#
# contentId                     ...            9191014301634017491  \
# personId                      ...
# -9223121837663643404          ...                            0.0
# -9212075797126931087          ...                            0.0
# -9207251133131336884          ...                            0.0
# -9199575329909162940          ...                            0.0
# -9196668942822132778          ...                            0.0
# -9188188261933657343          ...                            0.0
# -9172914609055320039          ...                            0.0
# -9156344805277471150          ...                            0.0
# -9120685872592674274          ...                            0.0
# -9109785559521267180          ...                            0.0
#
# contentId              9207286802575546269   9208127165664287660  \
# personId
# -9223121837663643404                   0.0                   0.0
# -9212075797126931087                   0.0                   0.0
# -9207251133131336884                   0.0                   0.0
# -9199575329909162940                   0.0                   0.0
# -9196668942822132778                   0.0                   0.0
# -9188188261933657343                   0.0                   0.0
# -9172914609055320039                   0.0                   0.0
# -9156344805277471150                   0.0                   0.0
# -9120685872592674274                   0.0                   0.0
# -9109785559521267180                   0.0                   0.0
#
# contentId              9209629151177723638   9209886322932807692  \
# personId
# -9223121837663643404                   0.0                   0.0
# -9212075797126931087                   0.0                   0.0
# -9207251133131336884                   0.0                   0.0
# -9199575329909162940                   0.0                   0.0
# -9196668942822132778                   0.0                   0.0
# -9188188261933657343                   0.0                   0.0
# -9172914609055320039                   0.0                   0.0
# -9156344805277471150                   0.0                   0.0
# -9120685872592674274                   0.0                   0.0
# -9109785559521267180                   0.0                   0.0
#
# contentId              9213260650272029784   9215261273565326920  \
# personId
# -9223121837663643404                   0.0                   0.0
# -9212075797126931087                   0.0                   0.0
# -9207251133131336884                   0.0                   0.0
# -9199575329909162940                   0.0                   0.0
# -9196668942822132778                   0.0                   0.0
# -9188188261933657343                   0.0                   0.0
# -9172914609055320039                   0.0                   0.0
# -9156344805277471150                   0.0                   0.0
# -9120685872592674274                   0.0                   0.0
# -9109785559521267180                   0.0                   0.0
#
# contentId              9217155070834564627   9220445660318725468  \
# personId
# -9223121837663643404                   0.0                   0.0
# -9212075797126931087                   0.0                   0.0
# -9207251133131336884                   0.0                   0.0
# -9199575329909162940                   0.0                   0.0
# -9196668942822132778                   0.0                   0.0
# -9188188261933657343                   0.0                   0.0
# -9172914609055320039                   0.0                   0.0
# -9156344805277471150                   0.0                   0.0
# -9120685872592674274                   0.0                   0.0
# -9109785559521267180                   0.0                   0.0
#
# contentId              9222265156747237864
# personId
# -9223121837663643404                   0.0
# -9212075797126931087                   0.0
# -9207251133131336884                   0.0
# -9199575329909162940                   0.0
# -9196668942822132778                   0.0
# -9188188261933657343                   0.0
# -9172914609055320039                   0.0
# -9156344805277471150                   0.0
# -9120685872592674274                   0.0
# -9109785559521267180                   0.0
#
# [10 rows x 2926 columns]

# %%
# get uer-item scores matrix
scores_matrix = scores_df.values # user-item score matrix
print("user-item scores matrix: ({:d}, {:d})".format(scores_matrix.shape[0], scores_matrix.shape[1]))
# Out:
# user-item scores matrix: (1140, 2926)

# %%
# perform matrix factorization
U, sigma, Vt = svds(scores_matrix, k=n_factors) # factorized user-item score matrix
print("U: ({:d}, {:d})".format(U.shape[0], U.shape[1]))
print("sigma: ({:d})".format(len(sigma)))
print("Vt: ({:d}, {:d})".format(Vt.shape[0], Vt.shape[1]))
# Out:
# U: (1140, 15)
# sigma: (15)
# Vt: (15, 2926)

# %%
# reconstruct scores
scores_predicted_matrix =  np.dot(np.dot(U, np.diag(sigma)) , Vt)

# %%
# creat score data frame from score matrix
scores_predicted_df = pd.DataFrame(scores_predicted_matrix,
                                   columns=scores_df.columns,
                                   index=scores_df.index).transpose()
print("item-user predicted data frame: ({:d}, {:d})".format(scores_predicted_df.shape[0],
                                                            scores_predicted_df.shape[1]))
scores_predicted_df.head(10)
# Out:
# item-user predicted data frame: (2926, 1140)
# personId              -9223121837663643404  -9212075797126931087  \
# contentId
# -9222795471790223670              0.004850             -0.000456
# -9216926795620865886              0.000292             -0.000230
# -9194572880052200111             -0.023040             -0.001931
# -9192549002213406534              0.038676              0.000897
# -9190737901804729417              0.019836             -0.006450
# -9189659052158407108              0.005947              0.006662
# -9176143510534135851              0.040836              0.007425
# -9172673334835262304              0.004451              0.000650
# -9171475473795142532              0.030142             -0.000801
# -9166778629773133902              0.009544             -0.002217
#
# personId              -9207251133131336884  -9199575329909162940  \
# contentId
# -9222795471790223670             -0.010169              0.058784
# -9216926795620865886              0.007730             -0.000269
# -9194572880052200111             -0.009119             -0.003649
# -9192549002213406534             -0.035799             -0.006191
# -9190737901804729417              0.011248              0.007434
# -9189659052158407108              0.002814             -0.003675
# -9176143510534135851              0.013606              0.011935
# -9172673334835262304              0.002204             -0.000824
# -9171475473795142532              0.000428             -0.006268
# -9166778629773133902             -0.014063             -0.002275
#
# personId              -9196668942822132778  -9188188261933657343  \
# contentId
# -9222795471790223670             -0.009780             -0.004324
# -9216926795620865886              0.000119              0.000272
# -9194572880052200111              0.024948             -0.001720
# -9192549002213406534              0.018377              0.004600
# -9190737901804729417             -0.003242              0.002913
# -9189659052158407108              0.008263             -0.001208
# -9176143510534135851             -0.003528             -0.004621
# -9172673334835262304              0.000413              0.000522
# -9171475473795142532              0.002805              0.001227
# -9166778629773133902              0.005068             -0.000040
#
# personId              -9172914609055320039  -9156344805277471150  \
# contentId
# -9222795471790223670             -0.004453              0.045504
# -9216926795620865886              0.000109              0.000720
# -9194572880052200111              0.030106             -0.015879
# -9192549002213406534              0.014409              0.054316
# -9190737901804729417              0.002350              0.004552
# -9189659052158407108              0.003291              0.002198
# -9176143510534135851              0.015342              0.023478
# -9172673334835262304              0.001259              0.002071
# -9171475473795142532              0.011491             -0.003140
# -9166778629773133902              0.001485              0.004248
#
# personId              -9120685872592674274  -9109785559521267180  \
# contentId
# -9222795471790223670             -0.001874             -0.018940
# -9216926795620865886              0.002665              0.001426
# -9194572880052200111             -0.022432              0.004695
# -9192549002213406534              0.049604              0.004401
# -9190737901804729417             -0.030522              0.020258
# -9189659052158407108              0.022154              0.020830
# -9176143510534135851              0.066618              0.058955
# -9172673334835262304             -0.002745              0.003111
# -9171475473795142532             -0.011298              0.026195
# -9166778629773133902              0.012544             -0.003614
#
# personId                      ...            9105269044962898535  \
# contentId                     ...
# -9222795471790223670          ...                      -0.004182
# -9216926795620865886          ...                      -0.000224
# -9194572880052200111          ...                       0.011473
# -9192549002213406534          ...                       0.016444
# -9190737901804729417          ...                       0.002669
# -9189659052158407108          ...                       0.023496
# -9176143510534135851          ...                      -0.001988
# -9172673334835262304          ...                       0.004687
# -9171475473795142532          ...                       0.012625
# -9166778629773133902          ...                       0.001668
#
# personId               9109075639526981934   9135582630122950040  \
# contentId
# -9222795471790223670             -0.105448              0.000979
# -9216926795620865886              0.014717              0.000548
# -9194572880052200111              0.036327              0.011388
# -9192549002213406534              0.294301              0.006416
# -9190737901804729417              0.011687              0.002925
# -9189659052158407108              0.088919             -0.001883
# -9176143510534135851              0.063974             -0.017215
# -9172673334835262304              0.018105              0.000342
# -9171475473795142532              0.027591              0.000414
# -9166778629773133902              0.062148              0.000900
#
# personId               9137372837662939523   9148269800512008413  \
# contentId
# -9222795471790223670              0.014130              0.031989
# -9216926795620865886              0.001504              0.016964
# -9194572880052200111              0.020062              0.176805
# -9192549002213406534             -0.010134              0.038508
# -9190737901804729417              0.000012             -0.047209
# -9189659052158407108              0.002615              0.098591
# -9176143510534135851              0.002521              0.006707
# -9172673334835262304             -0.000935             -0.006550
# -9171475473795142532              0.000016             -0.027984
# -9166778629773133902             -0.003938              0.009830
#
# personId               9165571805999894845   9187866633451383747  \
# contentId
# -9222795471790223670             -0.008898             -0.018234
# -9216926795620865886              0.001024              0.002117
# -9194572880052200111              0.021631              0.025802
# -9192549002213406534              0.012372              0.009922
# -9190737901804729417             -0.001835             -0.000264
# -9189659052158407108              0.007871              0.014248
# -9176143510534135851             -0.001435              0.004142
# -9172673334835262304              0.000222              0.002559
# -9171475473795142532              0.002073              0.010670
# -9166778629773133902              0.003576              0.002912
#
# personId               9191849144618614467   9199170757466086545  \
# contentId
# -9222795471790223670             -0.025583             -0.020703
# -9216926795620865886              0.009375              0.004455
# -9194572880052200111             -0.023756              0.009584
# -9192549002213406534             -0.018816              0.022117
# -9190737901804729417              0.009215              0.005795
# -9189659052158407108              0.017763              0.021165
# -9176143510534135851              0.040240              0.029514
# -9172673334835262304              0.002473              0.006003
# -9171475473795142532              0.000198              0.016424
# -9166778629773133902             -0.008748              0.000200
#
# personId               9210530975708218054
# contentId
# -9222795471790223670             -0.020562
# -9216926795620865886              0.003716
# -9194572880052200111              0.141702
# -9192549002213406534              0.106348
# -9190737901804729417             -0.022221
# -9189659052158407108              0.067955
# -9176143510534135851              0.050995
# -9172673334835262304             -0.001903
# -9171475473795142532             -0.007493
# -9166778629773133902              0.021179
#
# [10 rows x 1140 columns]

# %%
user_id = -9223121837663643404
items_to_ignore =[]
user_scores_df = scores_predicted_df[user_id].sort_values(ascending=False).reset_index().rename(columns={user_id: score_column}).head(5)

# %%
user_scores_df[~user_scores_df[content_column].isin(items_to_ignore)]
# Out:
#              contentId  eventStrength
# 0 -8208801367848627943       0.405222
# 1   943818026930898372       0.298944
# 2  2072448887839540892       0.264123
# 3  3149164017776669829       0.261815
# 4 -4029704725707465084       0.236790

# %%
user_scores_df[~user_scores_df[content_column].isin(items_to_ignore)].sort_values(score_column, ascending=False)
# Out:
#              contentId  eventStrength
# 0 -8208801367848627943       0.405222
# 1   943818026930898372       0.298944
# 2  2072448887839540892       0.264123
# 3  3149164017776669829       0.261815
# 4 -4029704725707465084       0.236790

# %%
# create model
collaborative_filter = CollaborativeFilter(scores_df=scores_predicted_df, items_df=articles_df)
collaborative_filter

# %%
collaborative_filter.recommend(-1479311724257856983,
                               content_column,
                               score_column,)
# Out:
#                 contentId  eventStrength
# 204  -8085935119790093311       1.047726
# 1965  3269302169678465882       0.975446
# 1612  1005751836898964351       0.935801
# 407  -6727357771678896471       0.933358
# 156  -8377626164558006982       0.886154
# 645  -5253644367331262405       0.877353
# 2632  7395435905985567130       0.872180
# 189  -8190931845319543363       0.868841
# 1696  1549650080907932816       0.857511
# 2262  5092635400707338872       0.832094

# %% [markdown]
# ### Preform recommendations

# %%
model_evaluator = RecallTopN(
    full_interactions_df=full_interactions_df,
    test_interactions_df=test_interactions_df,
    train_interactions_df=train_interactions_df,
    items_df=articles_df,
    content_id=content_column,
    score_id=score_column,
    sample_size=100)

overall_results_df, detailed_results_df = model_evaluator.evaluate(collaborative_filter)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-a535e1ecde02> in <module>()
#       6     content_id=content_column,
#       7     score_id=score_column,
# ----> 8     sample_size=100)
#       9
#      10 overall_results_df, detailed_results_df = model_evaluator.evaluate(collaborative_filter)
#
# TypeError: __init__() got an unexpected keyword argument 'content_id'

# %%
overall_results_df.head(10)

# %%
detailed_results_df.head(10)
